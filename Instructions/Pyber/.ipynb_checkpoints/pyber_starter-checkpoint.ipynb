# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np



# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data_df=pd.read_csv(city_data_to_load)
ride_data_df=pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
combined_city_ride_df=pd.merge(ride_data_df,city_data_df,how='left',on='city')

# Display the data table for preview
combined_city_ride_df.head(5)
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
combined_city_ride_df['type'].value_counts()
# Out:
# Urban       1625
# Suburban     625
# Rural        125
# Name: type, dtype: int64

# %%
city_type=combined_city_ride_df.groupby(['type','city'])

Ave_fare=round(city_type['fare'].mean(),2)
TotalRides=city_type['ride_id'].count()
TotalDrivers=city_type['driver_count'].sum()
Totalfare_byCityType=city_type['fare'].sum()


city_ride_df = pd.DataFrame({"Total Fare":Totalfare_byCityType,"Average Fare":Ave_fare,
                             "Total Rides":TotalRides,
                             "Total Drivers":TotalDrivers})


city_ride_df=city_ride_df.reset_index()
city_ride_df.head(50)
#city_ride_df.tail()
# Out:
#         type                city  Total Fare  Average Fare  \
# 0      Rural        Bradshawfurt      400.64         40.06
# 1      Rural           Garzaport       72.37         24.12
# 2      Rural      Harringtonfort      200.82         33.47
# 3      Rural         Jessicaport      216.08         36.01
# 4      Rural          Lake Jamie      206.15         34.36
# 5      Rural     Lake Latoyabury      286.68         26.06
# 6      Rural         Michaelberg      419.97         35.00
# 7      Rural        New Ryantown      259.67         43.28
# 8      Rural          Newtonview      146.98         36.75
# 9      Rural         North Holly      262.17         29.13
# 10     Rural         North Jaime      246.42         30.80
# 11     Rural         Penaborough      176.23         35.25
# 12     Rural      Randallchester      148.71         29.74
# 13     Rural      South Jennifer      246.85         35.26
# 14     Rural   South Marychester      334.96         41.87
# 15     Rural     South Saramouth      144.64         36.16
# 16     Rural         Taylorhaven      253.58         42.26
# 17     Rural        West Heather      305.01         33.89
# 18  Suburban       Barronchester      582.76         36.42
# 19  Suburban         Bethanyland      593.21         32.96
# 20  Suburban         Brandonfort      673.31         35.44
# 21  Suburban         Colemanland      679.68         30.89
# 22  Suburban           Davidfurt      543.93         32.00
# 23  Suburban      East Aaronbury      230.95         25.66
# 24  Suburban     East Danielview      536.53         31.56
# 25  Suburban       East Kentstad      387.70         29.82
# 26  Suburban      East Marymouth      832.55         30.84
# 27  Suburban           Grayville      416.45         27.76
# 28  Suburban          Josephside      887.17         32.86
# 29  Suburban            Lake Ann      370.68         30.89
# 30  Suburban           Lake Omar      393.05         28.07
# 31  Suburban     Lake Robertside      781.55         31.26
# 32  Suburban          Lake Scott      573.95         31.89
# 33  Suburban          Lewishaven      302.90         25.24
# 34  Suburban           Lewisland      588.44         34.61
# 35  Suburban         Mezachester      522.92         30.76
# 36  Suburban          Myersshire      483.25         30.20
# 37  Suburban          New Olivia      578.92         34.05
# 38  Suburban         New Raymond      615.16         27.96
# 39  Suburban     New Shannonberg      482.43         28.38
# 40  Suburban       Nicolechester      587.28         30.91
# 41  Suburban       North Jeffrey      380.15         29.24
# 42  Suburban  North Richardhaven      345.86         24.70
# 43  Suburban       North Timothy      468.93         31.26
# 44  Suburban          Port Shane      590.48         31.08
# 45  Suburban       Rodriguezview      461.18         30.75
# 46  Suburban           Sotoville      351.78         31.98
# 47  Suburban        South Brenda      815.15         33.96
# 48  Suburban        South Teresa      686.85         31.22
# 49  Suburban        Veronicaberg      558.08         32.83
#
#     Total no of Rides (Per City)  Total Drivers
# 0                             10             70
# 1                              3             21
# 2                              6             24
# 3                              6              6
# 4                              6             24
# 5                             11             22
# 6                             12             72
# 7                              6             12
# 8                              4              4
# 9                              9             72
# 10                             8              8
# 11                             5             30
# 12                             5             45
# 13                             7             49
# 14                             8              8
# 15                             4             28
# 16                             6              6
# 17                             9             36
# 18                            16            176
# 19                            18            396
# 20                            19            190
# 21                            22            506
# 22                            17            391
# 23                             9             63
# 24                            17            374
# 25                            13            260
# 26                            27            135
# 27                            15             30
# 28                            27            675
# 29                            12             36
# 30                            14            308
# 31                            25            100
# 32                            18            414
# 33                            12            276
# 34                            17             68
# 35                            17            238
# 36                            16            304
# 37                            17            340
# 38                            22            374
# 39                            17            340
# 40                            19            361
# 41                            13            143
# 42                            14             14
# 43                            15            105
# 44                            19            133
# 45                            15            300
# 46                            11            110
# 47                            24             24
# 48                            22            462
# 49                            17            340

# %%
#city_ride_df.plot(kind='scatter',x="Total no of Rides (Per City)",y="Average Fare", s=city_ride_df['Total Drivers'],
                  #c="Total no of Rides (Per City)",cmap="Blues",alpha=2,edgecolor='grey',figsize=(15,10), title="Pyber Ride sharing data (2016)")
#plt.show()

# %%
urban_df=city_ride_df.loc[city_ride_df['type']=='Urban']
suburban_df=city_ride_df.loc[city_ride_df['type']=='Suburban']
rural_df=city_ride_df.loc[city_ride_df['type']=='Rural']

# %%
# Show plot
plt.scatter(urban_df["Total no of Rides (Per City)"],urban_df["Average Fare"], s=urban_df['Total Drivers'],
            marker ='o', facecolors ="lightcoral", edgecolors='black',alpha = 0.5, label="Urban")
plt.scatter(suburban_df["Total no of Rides (Per City)"],suburban_df["Average Fare"], s=suburban_df['Total Drivers'],
            marker ='o', facecolors ="lightskyblue", edgecolors='black',alpha = 0.5, label="Suburban")
plt.scatter(rural_df["Total no of Rides (Per City)"],rural_df["Average Fare"], s=rural_df['Total Drivers'],
            marker ='o', facecolors ="gold", edgecolors='black',alpha = 0.5, label="Rural")

plt.legend(loc="best")

plt.title("Pyber Ride sharing data (2016)")
plt.xlabel("Total no of Rides (Per City)")
plt.ylabel("Average Fare")
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

grpByType=city_ride_df.groupby("type")
TotalFarebytype=grpByType["Total Fare"].sum()

TotalFare_allType=round(TotalFarebytype.sum(axis=0),2)

Type_percents=round(TotalFarebytype/TotalFare_allType*100,1)

TotalFares_df=pd.DataFrame({"Total Fare":TotalFarebytype,
                            "Fare percent":Type_percents })

TotalFares_df=TotalFares_df.reset_index()

# Build Pie Chart

labels=["Rural","Suburban","Urban"]
explode = (0,0,0.1)
colors = ["yellow","cyan","lightcoral"]
plot = TotalFares_df.plot(kind='Pie',y='Fare percent', figsize=(6, 6),explode=explode,labels=labels,
                          autopct="%1.1f%%",colors=colors,shadow=True,startangle=140,title="Total Fares by City Type")
plt.axis("equal")

# Save Figure
plt.savefig("../Images/TotalFareByCityType.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
grpByType=city_ride_df.groupby("type")
TotalFarebytype=grpByType["Total Fare"].sum()

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
